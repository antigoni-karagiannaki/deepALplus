# %%
# !python demo.py -a WAAL -s 100 -q 1000 -b 100 -d MNIST --seed 4666 -t 3 -g 0
# Out:
# ...
#   0%|                                                                        | 0/20 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\antig\AppData\Local\Programs\Python\Python311\Lib\multiprocessing\spawn.py", line 120, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\antig\AppData\Local\Programs\Python\Python311\Lib\multiprocessing\spawn.py", line 129, in _main
#     prepare(preparation_data)
#   File "C:\Users\antig\AppData\Local\Programs\Python\Python311\Lib\multiprocessing\spawn.py", line 240, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\antig\AppData\Local\Programs\Python\Python311\Lib\multiprocessing\spawn.py", line 291, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen runpy>", line 291, in run_path
# ...
